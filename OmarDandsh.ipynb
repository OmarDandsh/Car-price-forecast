# %%
import pandas as pd
import numpy as np
import tkinter as tk
from sklearn.svm import SVR
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression
from sklearn.neural_network import MLPRegressor
from tkinter import ttk
dataset=pd.read_excel("C:\\Users\\ACAD CENTER\\Desktop\\car.xlsx")
dataset["engine"]=dataset["engine"].str.replace("cc","")
dataset["car_prices_in_dollar"]=dataset["car_prices_in_dollar"].str.replace("$","")
dataset["car_prices_in_dollar"]=dataset["car_prices_in_dollar"].str.replace(",","")
dataset["car_prices_in_dollar"]=dataset["car_prices_in_dollar"].str.replace("dollar","")
dataset["Seats"]=dataset["Seats"].str.replace("Seats","")

dataset["ownership"]=dataset["ownership"].str.replace("st Owner","")
dataset["ownership"]=dataset["ownership"].str.replace("nd Owner","")
dataset["ownership"]=dataset["ownership"].str.replace("th Owner","")
dataset["ownership"]=dataset["ownership"].str.replace("rd Owner","")
dataset["kms_driven"]=dataset["kms_driven"].str.replace(" kms","")
dataset["kms_driven"]=dataset["kms_driven"].str.replace(",","")
dataset["engine"]=dataset["engine"].astype(float)
dataset["car_prices_in_dollar"]=dataset["car_prices_in_dollar"].astype(float)
dataset["kms_driven"]=dataset["kms_driven"].astype(float)
dataset["ownership"]=dataset["ownership"].astype(float)
dataset["Seats"]=dataset["Seats"].astype(float)
dataset.drop(columns=['car_name','ownership'])


il = dataset["fuel_type"].unique()
il1 = dataset["transmission"].unique()

il5= dataset["car_name"].unique()
il6= dataset["Type"].unique()
il7= dataset["maintenance"].unique()

encoder = preprocessing.LabelEncoder()
encoder.fit(il)
encodersmoker = preprocessing.LabelEncoder()
encodersmoker.fit(il1)

encoderregion3 = preprocessing.LabelEncoder()
encoderregion3.fit(il5)
encoderregion4 = preprocessing.LabelEncoder()
encoderregion4.fit(il6)
encoderregion5 = preprocessing.LabelEncoder()
encoderregion5.fit(il7)

#transform
dataset["fuel_type"] = encoder.transform(dataset["fuel_type"]) 
dataset["transmission"] = encodersmoker.transform(dataset["transmission"])

dataset["car_name"] = encoderregion3.transform(dataset["car_name"]) 
dataset["Type"] = encoderregion4.transform(dataset["Type"]) 
dataset["maintenance"] = encoderregion5.transform(dataset["maintenance"]) 

#print(dataset.isnull().mean())
#dataset['ownership'].unique()
imp = SimpleImputer(missing_values=np.nan, strategy='mean') 
imp = imp.fit(dataset)
dataset1 = imp.transform(dataset)

X = dataset1[:, :-1]
y= dataset1[:, -1]



from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,  random_state=32) 
X_train
X_test
y_train
y_test


lm=LinearRegression(fit_intercept=True,copy_X=True,n_jobs=10)
lm.fit(X_train, y_train)
y_pred = lm.predict(X_test)
y_pred
lm1 = MLPRegressor(random_state=1, max_iter=500)
lm1.fit(X_train, y_train)
y_pred1 = lm1.predict(X_test)
y_pred1

# تعريف الخوارزمية
svr = SVR(kernel='rbf', C=1.0, epsilon=0.2)
# التدريب
svr.fit(X_train, y_train)
# التنبؤ
y_pred2 = svr.predict(X_test)
# حساب معدل الخطأ التربيعي المتوسط
#mse = mean_squared_error(y_test, y_pred2)



from sklearn.metrics import mean_absolute_error


from sklearn.metrics import mean_squared_error
from tkinter import *
#-----------انشاء نافذة البرنامج------------
pro=Tk()
pro.geometry('1350x690+80+60')
pro.title(' التنبؤ باسعار السيارات')
nb=ttk.Notebook(pro)
nb.pack()
fr1=Frame(nb,width='1340',height='680',bg='silver')
nb.add(fr1,text='HOME')

fr2=Frame(nb,width='1340',height='680',bg='silver')
nb.add(fr2,text='Regression')

report=Frame(nb,width='1340',height='680',bg='white')
nb.add(report,text='Report')
pro.configure(background="silver"
             )
title=Label(fr1,text='[ برنامج التنبؤ باسعار السيارات ]',
font=('monospace',17),bg='#1AACEB',fg='white')
title.pack(fill=X)
#----------قائمة التعليمات----------
Manage_Frame=Frame(fr1,bg='white')
Manage_Frame.place(x=1,y=33,width=560,height=150)
lbl1=Label(fr1,text='اختيار الخوارزمية',fg='white',bg='#e84118',font=('Deco',14))
lbl1.place(x=1,y=33,width=560, height=25)

Manage_FrameLift=Frame(fr1,bg='white')
Manage_FrameLift.place(x=566,y=33,width=770,height=150)
lbl2=Label(fr1,text='الخصائص',fg='white',bg='#e84118',font=('Deco',14))
lbl2.place(x=566,y=33,width=770, height=25)

from PIL import Image, ImageTk
from tkinter import ttk

titl='''
الجامعة الدولية للعلوم والنهضة
            
            الهندسة المعلوماتية 
               
               السنة الرابعة
'''

unversty=Label(report,text=titl,fg='#4834d4',font=('Deco',18),bg='white',relief=RAISED, borderwidth=10, pady=55)
unversty.place(x=1000,y=10,width=320, height=170)

matriol='Machine Learning'
matriolLabel=Label(report,text=matriol,fg='#eb4d4b',bg='white',font=('Engravers MT',32))
matriolLabel.place(x=350,y=1,width=650, height=50)
matriolLabel=Label(report,text='The program for predicting car prices',bg='white',fg='#273c75',font=(' Fixedsys',22))
matriolLabel.place(x=350,y=70,width=650, height=50)

textr=''' 
 تم تصميم هذ البرنامج لتنبؤ باسعار السيارات بناء على احدى عشر ميزة وهم     
'''
tex=Label(report,text=textr,fg='#eb4d4b',bg='white',font=('Deco',16))
tex.place(x=810,y=190,width=530, height=70)

textr1='''
                                                نوع السيارة
                       عدد الكيلومترات التي قطعتهم السيارة  
              الانتقال بين مقود السرعة اهو عادي ام اتومتيك     
                                         سنة صنع السيارة
                                                  ونوع المحرك 
                                          وعدد مقاعد السيارة 
تصنيف السيارة اهي شاحنة ام تكسي ام باص ام بيكاب
                                       وهل بها صيانة من قبل 
                                                 وسعر السيارة
                                                         الملكية
'''

tex1=Label(report,text=textr1,fg='#353b48',bg='white',font=('Deco',14))
tex1.place(x=980,y=240,width=330, height=230)

tex2=Label(report,text='تم استخدام ثلاث خوارزميات وهم ',bg='white',fg='#eb4d4b',font=('Deco',16))
tex2.place(x=1000,y=463,width=390, height=46)

textr2='''
SVR

MLPRegressor

LinearRegression

'''

tex2=Label(report,text=textr2,fg='#273c75',font=('Deco',14),bg='white')
tex2.place(x=1050,y=510,width=390, height=160)
textr3='''
حيث اعطت الدقة

حيث اعطت الدقة

حيث اعطت الدقة

'''
tex3=Label(report,text=textr3,fg='#2f3542',bg='white',font=('Deco',14))
tex3.place(x=1030,y=510,width=140, height=160)

textr4='''
5.89349

8.29172

7.97650

'''
tex4=Label(report,text=textr4,fg='#2ed573',bg='white',font=('Deco',14))
tex4.place(x=900,y=510,width=100, height=160)



tex5=Label(report,text='خطوات تنظيف قاعدة البيانات',bg='white',fg='#eb4d4b',font=('Deco',16),relief=RAISED, borderwidth=3)
tex5.place(x=470,y=190,width=230, height=70)
textr6='''

  تم تنظيف عامود السعر والكيلومترات والملكية وعدد المقاعد وسنة الصنع 
من البيانات المحارف والكلمات وتعديل القيم الكبيرة التي من الممكن تعطي دقة ضعيفة 
في التنبؤ الى المتوسط الحسابي وكذلك القيم الفارغة وتحويلهم إلى float 

'''
tex7=Label(report,text=textr6,bg='white',fg='#353b48',font=('Deco',16),relief=RAISED, borderwidth=3)
tex7.place(x=100,y=280,width=600, height=100)

textr9='''

تم تطبيق على كل من الاعمدة نوع الوقود واسم السيارة 
ونوع مقبض السرعة ونوع السيارة والصيانة خوارزمية preprocessing
من اجل تحويل الاعمد الى ارقام 

'''
tex11=Label(report,text=textr9,bg='white',fg='#353b48',font=('Deco',16),relief=RAISED, borderwidth=3)
tex11.place(x=100,y=390,width=600, height=100)

textr10='''

 تطبيق خوارزمية الانحراف المعياري 
 وتقسيم الداتا سيت والتنبؤ لايجاد اقرب دقة خالية 
 من الاخطاء 

'''

tex11=Label(report,text=textr10,fg='#353b48',bg='white',font=('Deco',16),relief=RAISED, borderwidth=3)
tex11.place(x=100,y=490,width=600, height=100)

lbl10=Label(fr1,text="  Mean Squared Error  ",fg='#ED4C67',bg='silver',font=12, wraplength = 270, relief = "groove")
lbl10.place(x=670,y=210)
lbl10=Label(fr1,text="  Mean Absolute Error  ",fg='#ED4C67',bg='silver',font=12, wraplength = 270, relief = "groove")
lbl10.place(x=270,y=210)
def LinearRegression():
    lbl1=Label(fr1,text=mean_squared_error(y_test, y_pred),fg='black',bg='silver',font=('Deco',12))
    lbl1.place(x=670,y=250,width=220, height=50)
    lbl1=Label(fr1,text=mean_absolute_error(y_test, y_pred),fg='black',bg='silver',font=('Deco',12))
    lbl1.place(x=270,y=250,width=220, height=50)

def MLPRegressor():
    
    lbl1=Label(fr1,text=mean_squared_error(y_test, y_pred1),fg='black',bg='silver',font=('Deco',12))
    lbl1.place(x=670,y=250,width=220, height=50)
    lbl1=Label(fr1,text=mean_absolute_error(y_test, y_pred1),fg='black',bg='silver',font=('Deco',12))
    lbl1.place(x=270,y=250,width=220, height=50)

def SVR():
    
    lbl1=Label(fr1,text=mean_squared_error(y_test, y_pred2),fg='black',bg='silver',font=('Deco',12))
    lbl1.place(x=670,y=250,width=220, height=50)
    lbl1=Label(fr1,text=mean_absolute_error(y_test, y_pred2),fg='black',bg='silver',font=('Deco',12))
    lbl1.place(x=270,y=250,width=220, height=50)    

LinearRegression=Button(Manage_Frame,text='LinearRegression',bg='#487eb0',font=('Deco',13),bd=5,fg='white',command=LinearRegression)
LinearRegression.place(x=33,y=50,width=150,height=60)
but2=Button(Manage_Frame,text='MLPRegressor',bg='#487eb0',font=('Deco',13),bd=5,fg='white',command=MLPRegressor)
but2.place(x=213,y=50,width=150,height=60)
SVR=Button(Manage_Frame,text='SVR',bg='#487eb0',font=('Deco',13),bd=5,fg='white',command=SVR)
SVR.place(x=393,y=50,width=150,height=60)

def size1():
    lbl1=Label(Manage_FrameLift,text=dataset.size,fg='black',font=('Deco',10))
    lbl1.place(x=129,y=45)
size=Button(Manage_FrameLift,text='number cells:',bd=5,bg='#487eb0',font=('Deco',10),fg='white',command=size1)
size.place(x=20,y=40,width=100,height=35)

def shape1():
    shape=Label(Manage_FrameLift,text=dataset.shape,fg='black',font=('Deco',10))
    shape.place(x=130,y=96)
shape=Button(Manage_FrameLift,text='shape :',bd=5,bg='#487eb0',font=('Deco',11),fg='white',command=shape1)
shape.place(x=20,y=90 ,width=100,height=35)

def columns():
    lbl1=Label(Manage_FrameLift,text=dataset.columns,fg='black',font=('Deco',10))
    lbl1.place(x=293,y=42 )
column=Button(Manage_FrameLift,text='Name colmns :',bd=5,bg='#487eb0',font=('Deco',11),fg='white',command=columns)
column.place(x=180,y=40,width=110,height=35)

def delete():
    lbl1=Label(Manage_FrameLift,text="",fg='black',font=('Deco',9),bg='white')
    lbl1.place(x=293,y=42 ,width=400,height=150 )
    shape=Label(Manage_FrameLift,text="",fg='black',font=('Deco',9),bg='white')
    shape.place(x=120,y=93,width=50,height=50)
    lbl2=Label(Manage_FrameLift,text="",fg='black',font=('Deco',10),bg='white')
    lbl2.place(x=119,y=42,width=50,height=50)

delet=Button(Manage_FrameLift,text=' Delete ',bg='red',font=('Deco',10),fg='white',bd=5,command=delete)
delet.place(x=700,y=102)


Manage_Frame1=Frame(fr2,bg='silver')
Manage_Frame1.place(x=1,y=33,width=1300,height=700)
def validate_num(S):
    if S.isdigit():
        return True
    else:
        return False

        
def predict(car_nameSelect_box,kms_drivenText_box,fuel_typeSelect_box,transmissionSelect_box,ownershipText_box,manufactureText_box,engineSelect_box,SeatsText_box,TypeSelect,maintenanceText_box):
    

    
    car_name=car_nameptions[car_nameSelect_box.current()]
    kms_driven = kms_drivenText_box.get()
    if kms_driven.isdigit():
        kms_driven = int(kms_driven)
    else:
        # handle the error for non-numeric or empty input
        
        return
    fuel_type=fuel_typeOptions[fuel_typeSelect_box.current()]
    transmission=transmissionOptions[transmissionSelect_box.current()]
    
    
    
    ownership = ownershipText_box.get()
    if ownership.isdigit():
        ownership = int(ownership)
    else:
        x=10
    manufacture=int(manufactureText_box.get())   
    engine=int(engineSelect_box.get())
    Seats=int(SeatsText_box.get())
    Type=TypeOptions[TypeSelect.current()]
    maintenance=maintenanceOptions[maintenanceText_box.current()]
   
    data=np.array([[car_name,kms_driven,fuel_type,transmission,ownership,manufacture,engine,Seats,Type,maintenance]])
    dataset = pd.DataFrame(data, columns=["car_name","kms_driven","fuel_type","transmission","ownership","manufacture","engine","Seats","Type","maintenance"])
    categorical_columns = ['car_name','fuel_type','transmission','Type','maintenance']
    dataset = pd.get_dummies(data = dataset, prefix = 'OHE', prefix_sep='_',columns = categorical_columns,dtype='int8')
    

    Finaldf= dataset.iloc[:, :]
    Finaldf=Finaldf.astype(float)
    OHEimp = SimpleImputer(missing_values=np.nan, strategy='mean')
    OHEimp = OHEimp.fit(Finaldf)
    Finaldf = OHEimp.transform(Finaldf)
    
    result=lm.predict(Finaldf)

    output_label.config(text=(f"{np.round(result[0]) } $"))
    








car_nameptions = ["HONDA", "Chevrolet", "DAIHATSU ","FORD","GMC","HONDA","kia","MAZDA","Mercedes Benz","PORSCHE","SUZUKI",]
car_nameLabel = tk.Label(Manage_Frame1, text="City",bg='silver',font=('Deco',11))
car_nameLabel.grid(row=1, column=0, padx=10, pady=1, sticky='W')
car_nameSelect_box = ttk.Combobox(Manage_Frame1, values=car_nameptions, width = 50)
car_nameSelect_box.grid(row=2, column=0, padx=10, pady=(1,20),ipady=7)
car_nameSelect_box.current(0) 


kms_drivenLabel = tk.Label(Manage_Frame1, text="kms Driven",bg='silver',font=('Deco',11))
kms_drivenLabel.grid(row=1, column=1, padx=10, pady=1, sticky='W')
kms_drivenText_box = tk.Entry(Manage_Frame1,validate='key', validatecommand=(Manage_Frame1.register(validate_num), '%S'), width = 50,relief="solid")
kms_drivenText_box.grid(row=2, column=1, padx=10, pady=(1,20),ipady=7)

fuel_typeOptions = ["Petrol", "Diesel","electric powered","Natural gas"]
fuel_typeLabel = tk.Label(Manage_Frame1, text="fuel_type",bg='silver',font=('Deco',11))
fuel_typeLabel.grid(row=1, column=2, padx=10, pady=1, sticky='W')
fuel_typeSelect_box = ttk.Combobox(Manage_Frame1, values=fuel_typeOptions, width = 50,)
fuel_typeSelect_box.grid(row=2, column=2, padx=10, pady=(1,20),ipady=7)
fuel_typeSelect_box.current(0)

transmissionOptions = ["Manual", "Automatic"]
transmissionLabel = tk.Label(Manage_Frame1, text="transmission",bg='silver',font=('Deco',11))
transmissionLabel.grid(row=1, column=3, padx=10, pady=1, sticky='W')
transmissionSelect_box = ttk.Combobox(Manage_Frame1, values=transmissionOptions, width = 40)
transmissionSelect_box.grid(row=2, column=3, padx=10, pady=(1,20),ipady=7)
transmissionSelect_box.current(0)

ownershipLabel = tk.Label(Manage_Frame1, text="ownership",bg='silver',font=('Deco',11))
ownershipLabel.grid(row=3, column=0, padx=10, pady=1, sticky='W')
ownershipText_box = tk.Entry(Manage_Frame1,validate='key', validatecommand=(Manage_Frame1.register(validate_num), '%S'), width = 50,relief="solid")
ownershipText_box.grid(row=4, column=0, padx=10, pady=(1,20),ipady=7)

manufactureLabel = tk.Label(Manage_Frame1, text="manufacture",bg='silver',font=('Deco',11))
manufactureLabel.grid(row=3, column=1, padx=10, pady=1, sticky='W')
manufactureText_box = tk.Entry(Manage_Frame1,validate='key', validatecommand=(Manage_Frame1.register(validate_num), '%S'), width = 50,relief="solid")
manufactureText_box.grid(row=4, column=1, padx=10, pady=(1,20),ipady=7)

engineLabel = tk.Label(Manage_Frame1, text="engine",bg='silver',font=('Deco',11))
engineLabel.grid(row=3, column=3, padx=10, pady=1, sticky='W')
engineRoomsText_box = tk.Entry(Manage_Frame1,validate='key', validatecommand=(Manage_Frame1.register(validate_num), '%S'), width = 40,relief="solid")
engineRoomsText_box.grid(row=4, column=3, padx=10, pady=(1,20),ipady=7)

SeatsLabel = tk.Label(Manage_Frame1, text="Seats",bg='silver',font=('Deco',11))
SeatsLabel.grid(row=5, column=0, padx=10, pady=1, sticky='W')
SeatsText_box = tk.Entry(Manage_Frame1,validate='key', validatecommand=(Manage_Frame1.register(validate_num), '%S'), width = 50,relief="solid")
SeatsText_box.grid(row=6, column=0, padx=10, pady=(1,20),ipady=7)

TypeOptions = ["Taxi", "Pick up","Bus","Truck"]
TypeLabel = tk.Label(Manage_Frame1, text="Type",bg='silver',font=('Deco',11))
TypeLabel.grid(row=5, column=1, padx=10, pady=1, sticky='W')
TypeSelect_box = ttk.Combobox(Manage_Frame1, values=TypeOptions, width = 50)
TypeSelect_box.grid(row=6, column=1, padx=10, pady=(1,20),ipady=7)
TypeSelect_box.current(0)



maintenanceOptions = ["Yes","No"]
maintenanceLabel1 = tk.Label(Manage_Frame1, text="maintenance",bg='silver',font=('Deco',11))
maintenanceLabel1.grid(row=3, column=2, padx=10, pady=1, sticky='W')
maintenanceSelect_box1 = ttk.Combobox(Manage_Frame1, values=maintenanceOptions, width = 50)
maintenanceSelect_box1.grid(row=4, column=2, padx=10, pady=(1,20),ipady=7)
maintenanceSelect_box1.current(0)


from tkinter import font

# Create an output label
output_label = tk.Label(Manage_Frame1, text="",bg='silver')
output_label.config(font=('arial', 30))
output_label.grid(row=7, column=1,  padx=10, pady=10)

# Create a predict button

predict_button = tk.Button(Manage_Frame1,font=('Deco',14), text="Predict",width=18,height=2,relief="solid", command=lambda: predict(car_nameSelect_box,kms_drivenText_box,fuel_typeSelect_box,transmissionSelect_box,ownershipText_box,manufactureText_box,engineRoomsText_box,SeatsText_box,TypeSelect_box,maintenanceSelect_box1))
myFont = font.Font(size=20)
predict_button.grid(row=7, column=0,  padx=5, pady=10)






from PIL import Image, ImageTk
image1 = Image.open("C:\\Users\\ACAD CENTER\\Desktop\\image\\taks.png")
test = ImageTk.PhotoImage(image1)
label1 = Label(fr2,image=test)
label1.image = test
label1.place(x=150, y=450)

bus = Image.open("C:\\Users\\ACAD CENTER\\Desktop\\image\\trian.png")
test1 = ImageTk.PhotoImage(bus)
label2 = Label(fr2,image=test1)
label2.image = test1
label2.place(x=500, y=450 ,width=280,height=187)


trin = Image.open("C:\\Users\\ACAD CENTER\\Desktop\\image\\bus.png")
test2 = ImageTk.PhotoImage(trin)
label3 = Label(fr2,image=test2)
label3.image = test2
label3.place(x=850, y=450 ,width=280,height=187)


#------------------image Home------------


busHome = Image.open("C:\\Users\\ACAD CENTER\\Desktop\\image\\taks.png")
test10 = ImageTk.PhotoImage(busHome)
label20 = Label(fr1,image=test10)
label20.image = test10
label20.place(x=300, y=450 ,width=280,height=187)


trinHome = Image.open("C:\\Users\\ACAD CENTER\\Desktop\\image\\trians.jpg")
test20 = ImageTk.PhotoImage(trinHome)
label30 = Label(fr1,image=test20)
label30.image = test20
label30.place(x=650, y=450 ,width=280,height=187)









pro.mainloop()
